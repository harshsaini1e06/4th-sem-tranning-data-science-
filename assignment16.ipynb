# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("StudentsPerformance.csv")
df
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0     male        group A          associate's degree  free/reduced
# 1     male        group C                some college      standard
# 2     male        group B                some college  free/reduced
# 3     male        group D                 high school  free/reduced
# 4     male        group C          associate's degree      standard
# ..     ...            ...                         ...           ...
# 477   male        group A                 high school      standard
# 478   male        group E            some high school      standard
# 479   male        group E                 high school  free/reduced
# 480   male        group A                 high school      standard
# 481   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          47             57             44
# ...

# %%
df.head() # it shows the first 5 rows only
# Out:
#   gender race/ethnicity parental level of education         lunch  \
# 0   male        group A          associate's degree  free/reduced
# 1   male        group C                some college      standard
# 2   male        group B                some college  free/reduced
# 3   male        group D                 high school  free/reduced
# 4   male        group C          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          47             57             44
# 1                    none          76             78             75
# 2                    none          40             43             39
# 3               completed          64             64             67
# 4                    none          58             54             52

# %%
df.tail() # it shows the values of last 5 rows
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 477   male        group A                 high school      standard
# 478   male        group E            some high school      standard
# 479   male        group E                 high school  free/reduced
# 480   male        group A                 high school      standard
# 481   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 477                    none          57             51             54
# 478               completed          81             75             76
# 479               completed          86             81             75
# 480                    none          63             63             62
# 481                    none          62             55             55

# %%
df.shape
# Out:
# (482, 8)

# %%
df.info() # in this objest data type is string
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 482 entries, 0 to 481
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       482 non-null    object
#  1   race/ethnicity               482 non-null    object
#  2   parental level of education  482 non-null    object
#  3   lunch                        482 non-null    object
#  4   test preparation course      482 non-null    object
#  5   math score                   482 non-null    int64
#  6   reading score                482 non-null    int64
#  7   writing score                482 non-null    int64
# dtypes: int64(3), object(5)
# memory usage: 30.3+ KB

# %%
df[["gender","lunch"]]
# Out:
#     gender         lunch
# 0     male  free/reduced
# 1     male      standard
# 2     male  free/reduced
# 3     male  free/reduced
# 4     male      standard
# ..     ...           ...
# 477   male      standard
# 478   male      standard
# 479   male  free/reduced
# 480   male      standard
# 481   male  free/reduced
#
# [482 rows x 2 columns]

# %%
type(df['gender'])  # single column in single square brackets shows the series not dataframes
# Out:
# pandas.core.series.Series

# %%
df.loc[100:110,['math score','gender']] # in loc indexing of columns are not possible
# Out:
#      math score gender
# 100          69   male
# 101          59   male
# 102          74   male
# 103          82   male
# 104          81   male
# 105          80   male
# 106          35   male
# 107          60   male
# 108          87   male
# 109          84   male
# 110          66   male

# %%
df['reading score'].sum() # similarly max , mean , sum , etc.
# df['price'].min() # similarly max , mean , sum , etc.
# Out:
# 31558

# %%
df ['gender'].value_counts()
# Out:
# gender
# male    482
# Name: count, dtype: int64

# %%
male = df[df ['gender']=="male"]
male
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0     male        group A          associate's degree  free/reduced
# 1     male        group C                some college      standard
# 2     male        group B                some college  free/reduced
# 3     male        group D                 high school  free/reduced
# 4     male        group C          associate's degree      standard
# ..     ...            ...                         ...           ...
# 477   male        group A                 high school      standard
# 478   male        group E            some high school      standard
# 479   male        group E                 high school  free/reduced
# 480   male        group A                 high school      standard
# 481   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          47             57             44
# ...

# %%
male.to_csv("StudentsPerformance.csv",index=False)
male
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0     male        group A          associate's degree  free/reduced
# 1     male        group C                some college      standard
# 2     male        group B                some college  free/reduced
# 3     male        group D                 high school  free/reduced
# 4     male        group C          associate's degree      standard
# ..     ...            ...                         ...           ...
# 477   male        group A                 high school      standard
# 478   male        group E            some high school      standard
# 479   male        group E                 high school  free/reduced
# 480   male        group A                 high school      standard
# 481   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          47             57             44
# ...

# %%
df['math score'].value_counts()
# Out:
# math score
# 62    19
# 61    16
# 69    16
# 68    15
# 73    14
#       ..
# 99     1
# 42     1
# 43     1
# 35     1
# 36     1
# Name: count, Length: 68, dtype: int64

# %%
writing = df['writing score'].min()
writing
# Out:
# 15

# %%
df
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0     male        group A          associate's degree  free/reduced
# 1     male        group C                some college      standard
# 2     male        group B                some college  free/reduced
# 3     male        group D                 high school  free/reduced
# 4     male        group C          associate's degree      standard
# ..     ...            ...                         ...           ...
# 477   male        group A                 high school      standard
# 478   male        group E            some high school      standard
# 479   male        group E                 high school  free/reduced
# 480   male        group A                 high school      standard
# 481   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          47             57             44
# ...

# %%
fg = df[df['reading score']<=50]
fg
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 2     male        group B                some college  free/reduced
# 8     male        group C             master's degree  free/reduced
# 15    male        group D                some college      standard
# 25    male        group C                some college      standard
# 30    male        group A            some high school  free/reduced
# ..     ...            ...                         ...           ...
# 438   male        group B                 high school      standard
# 440   male        group D           bachelor's degree  free/reduced
# 448   male        group E          associate's degree  free/reduced
# 462   male        group B            some high school  free/reduced
# 474   male        group D                 high school      standard
#
#     test preparation course  math score  reading score  writing score
# 2                      none          40             43             39
# ...

# %%
fg.reset_index(drop=True) # in this the use of drop option is used to remove the old indexing
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group B                some college  free/reduced
# 1    male        group C             master's degree  free/reduced
# 2    male        group D                some college      standard
# 3    male        group C                some college      standard
# 4    male        group A            some high school  free/reduced
# ..    ...            ...                         ...           ...
# 60   male        group B                 high school      standard
# 61   male        group D           bachelor's degree  free/reduced
# 62   male        group E          associate's degree  free/reduced
# 63   male        group B            some high school  free/reduced
# 64   male        group D                 high school      standard
#
#    test preparation course  math score  reading score  writing score
# 0                     none          40             43             39
# ...

# %%
race = df[df['race/ethnicity']=="group D"]
race
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group D                 high school  free/reduced
# 5     male        group D          associate's degree      standard
# 9     male        group D                 high school      standard
# 10    male        group D                some college      standard
# 11    male        group D           bachelor's degree  free/reduced
# ..     ...            ...                         ...           ...
# 456   male        group D                some college      standard
# 457   male        group D            some high school      standard
# 468   male        group D                some college      standard
# 474   male        group D                 high school      standard
# 475   male        group D            some high school      standard
#
#     test preparation course  math score  reading score  writing score
# 3                 completed          64             64             67
# ...

# %%
fg = df.sort_values(by='writing score', ascending=False)

# %%
fg.reset_index(drop=True) # in this the use of drop option is used to remove the old indexing
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0     male        group E           bachelor's degree      standard
# 1     male        group D                some college      standard
# 2     male        group C          associate's degree      standard
# 3     male        group E          associate's degree  free/reduced
# 4     male        group B          associate's degree      standard
# ..     ...            ...                         ...           ...
# 477   male        group C                some college  free/reduced
# 478   male        group B                 high school  free/reduced
# 479   male        group E            some high school      standard
# 480   male        group A                some college  free/reduced
# 481   male        group B                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                 completed         100            100            100
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['math score']+5
# Out:
# 0      52
# 1      81
# 2      45
# 3      69
# 4      63
#        ..
# 477    62
# 478    86
# 479    91
# 480    68
# 481    67
# Name: math score, Length: 482, dtype: int64

# %%
df['math_marks_increased'] = df['math score']+5

# %%
df
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0     male        group A          associate's degree  free/reduced
# 1     male        group C                some college      standard
# 2     male        group B                some college  free/reduced
# 3     male        group D                 high school  free/reduced
# 4     male        group C          associate's degree      standard
# ..     ...            ...                         ...           ...
# 477   male        group A                 high school      standard
# 478   male        group E            some high school      standard
# 479   male        group E                 high school  free/reduced
# 480   male        group A                 high school      standard
# 481   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          47             57             44
# ...

# %%
df['test preparation course'].value_counts()
# Out:
# test preparation course
# none         308
# completed    174
# Name: count, dtype: int64

# %%
df[['math_marks_increased']].mean()
# Out:
# math_marks_increased    73.728216
# dtype: float64

# %%
plt.plot(df['lunch'])

# %%
plt.plot(df['reading score'])

# %%
df['math score'],df['race/ethnicity']
plt.scatter(x=df['race/ethnicity'],y=df['math score'])
plt.xticks(rotation=90)
plt.show() # this function is used to hide the object value showen in the output

# %%
lable = list(df['race/ethnicity'].value_counts().keys())
lable
# Out:
# ['group C', 'group D', 'group B', 'group E', 'group A']

# %%
value = list(df['race/ethnicity'].value_counts().values)
value
# Out:
# [139, 133, 86, 71, 53]

# %%
plt.bar(lable,value)
plt.xticks(rotation=60)
plt.show()

# %%
df = sns.load_dataset('diamonds')
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0  326.0  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0  326.0  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0  327.0  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0  334.0  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0  335.0  4.34  4.35  2.75

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
# df = sns.load_dataset('brain_networks')
# df.head()

# %%
sns.relplot(x='cut',y='carat',data=df)

# %%
sns.relplot(x='cut',y='carat',data=df,hue='color',style='cut')

# %%
sns.relplot(x='color',y='table',data=df,hue='clarity',col='cut')

# %%
sns.relplot(x='color',y='table',data=df,hue='clarity',style='carat',col='cut')
plt.show()

# %%
sns.relplot(x='color',y='table',data=df,hue='clarity',style='carat',col='cut',kind='line')
plt.show()

# %%
df
# Out:
#        carat      cut color clarity  depth  table   price     x     y     z
# 0       0.23    Ideal     E     SI2   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21  Premium     E     SI1   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23     Good     E     VS1   56.9   65.0   327.0  4.05  4.07  2.31
# 3       0.29  Premium     I     VS2   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31     Good     J     SI2   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...      ...   ...     ...    ...    ...     ...   ...   ...   ...
# 16275   1.23    Ideal     G     SI1   61.4   56.0  6509.0  6.94  6.91  4.25
# 16276   1.51  Premium     H     SI2   62.9   58.0  6511.0  7.31  7.26  4.58
# 16277   1.51    Ideal     I     VS2   60.7   57.0  6511.0  7.42  7.35  4.48
# 16278   1.51     Good     J     SI1   64.1   61.0  6511.0  7.19  7.16  4.60
# 16279   1.20    Ideal     H     SI1   62.0    NaN     NaN   NaN   NaN   NaN
#
# [16280 rows x 10 columns]

# %%
sns.catplot(x='cut',y='price',data=df,hue='color')
plt.show()

# %%
sns.catplot(x='cut',y='price',data=df,kind='boxen',hue='color')
plt.show()

# %%
# sns.catplot(x='cut',y='price',data=df,kind='swarm')
# plt.show()

# %%
df
# Out:
#        carat      cut color clarity  depth  table   price     x     y     z
# 0       0.23    Ideal     E     SI2   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21  Premium     E     SI1   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23     Good     E     VS1   56.9   65.0   327.0  4.05  4.07  2.31
# 3       0.29  Premium     I     VS2   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31     Good     J     SI2   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...      ...   ...     ...    ...    ...     ...   ...   ...   ...
# 16275   1.23    Ideal     G     SI1   61.4   56.0  6509.0  6.94  6.91  4.25
# 16276   1.51  Premium     H     SI2   62.9   58.0  6511.0  7.31  7.26  4.58
# 16277   1.51    Ideal     I     VS2   60.7   57.0  6511.0  7.42  7.35  4.48
# 16278   1.51     Good     J     SI1   64.1   61.0  6511.0  7.19  7.16  4.60
# 16279   1.20    Ideal     H     SI1   62.0    NaN     NaN   NaN   NaN   NaN
#
# [16280 rows x 10 columns]

# %%
sns.scatterplot(x='carat',y='depth',data=df)
# Out:
# <Axes: xlabel='carat', ylabel='depth'>

# %%
sns.barplot(y='clarity',x='price',data=df)
# Out:
# <Axes: xlabel='price', ylabel='clarity'>

# %%
sns.barplot(x='carat',y='price',data=df)
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
df
# Out:
#        carat      cut color clarity  depth  table   price     x     y     z
# 0       0.23    Ideal     E     SI2   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21  Premium     E     SI1   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23     Good     E     VS1   56.9   65.0   327.0  4.05  4.07  2.31
# 3       0.29  Premium     I     VS2   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31     Good     J     SI2   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...      ...   ...     ...    ...    ...     ...   ...   ...   ...
# 16275   1.23    Ideal     G     SI1   61.4   56.0  6509.0  6.94  6.91  4.25
# 16276   1.51  Premium     H     SI2   62.9   58.0  6511.0  7.31  7.26  4.58
# 16277   1.51    Ideal     I     VS2   60.7   57.0  6511.0  7.42  7.35  4.48
# 16278   1.51     Good     J     SI1   64.1   61.0  6511.0  7.19  7.16  4.60
# 16279   1.20    Ideal     H     SI1   62.0    NaN     NaN   NaN   NaN   NaN
#
# [16280 rows x 10 columns]

# %%
df['cut'].value_counts()
# Out:
# cut
# Ideal        5143
# Premium      4461
# Very Good    4032
# Good         1938
# Fair          706
# Name: count, dtype: int64

# %%
sns.barplot(y='price',x='clarity',data=df,hue='cut')
# Out:
# <Axes: xlabel='clarity', ylabel='price'>

# %%
sns.catplot(x='z',y='x',data=df,hue='y')
plt.show()

# %%
lable = list(df['cut'].value_counts().keys())
lable
# Out:
# ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
value = list(df['cut'].value_counts().values)
value
# Out:
# [5143, 4461, 4032, 1938, 706]

# %%
plt.pie(value,labels=lable,wedgeprops={'ec':'white'},autopct="%1.2f%%",shadow=True) # wedgeprops is used to apply different colours at boundries
# here 'autopct' is used to show the values of percentage on the pie chart
# here shadow is used to ... as you know
plt.show()

# %%
df
# Out:
#        carat      cut color clarity  depth  table   price     x     y     z
# 0       0.23    Ideal     E     SI2   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21  Premium     E     SI1   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23     Good     E     VS1   56.9   65.0   327.0  4.05  4.07  2.31
# 3       0.29  Premium     I     VS2   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31     Good     J     SI2   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...      ...   ...     ...    ...    ...     ...   ...   ...   ...
# 16275   1.23    Ideal     G     SI1   61.4   56.0  6509.0  6.94  6.91  4.25
# 16276   1.51  Premium     H     SI2   62.9   58.0  6511.0  7.31  7.26  4.58
# 16277   1.51    Ideal     I     VS2   60.7   57.0  6511.0  7.42  7.35  4.48
# 16278   1.51     Good     J     SI1   64.1   61.0  6511.0  7.19  7.16  4.60
# 16279   1.20    Ideal     H     SI1   62.0    NaN     NaN   NaN   NaN   NaN
#
# [16280 rows x 10 columns]

# %%
df['color'].value_counts()
# Out:
# color
# H    3006
# G    2915
# F    2804
# E    2665
# D    2015
# I    1853
# J    1022
# Name: count, dtype: int64

# %%
sns.relplot(x='cut',y='color',data=df,kind='line')
# scatterplot is mainly used to compare the values

# %%
sns.relplot(x='cut',y='color',data=df,kind='line',hue='cut')
# scatterplot is mainly used to compare the values

# %%
sns.boxplot(df['price']) # in box plot only numerical values are used
# the values represented in shape of circles are called outliers. these outliers represent the major difference fron the main data
# Out:
# <Axes: ylabel='price'>

# %%
sns.boxplot(df['x']) # in box plot only numerical values are used
# the values represented in shape of circles are called outliers. these outliers represent the major difference fron the main data
# Out:
# <Axes: ylabel='x'>

# %%
sns.boxplot(df['y']) # in box plot only numerical values are used
# the values represented in shape of circles are called outliers. these outliers represent the major difference fron the main data
# Out:
# <Axes: ylabel='y'>

# %%
sns.boxplot(df['z']) # in box plot only numerical values are used
# the values represented in shape of circles are called outliers. these outliers represent the major difference fron the main data
# Out:
# <Axes: ylabel='z'>

# %%
df
# Out:
#        carat      cut color clarity  depth  table   price     x     y     z
# 0       0.23    Ideal     E     SI2   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21  Premium     E     SI1   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23     Good     E     VS1   56.9   65.0   327.0  4.05  4.07  2.31
# 3       0.29  Premium     I     VS2   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31     Good     J     SI2   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...      ...   ...     ...    ...    ...     ...   ...   ...   ...
# 16275   1.23    Ideal     G     SI1   61.4   56.0  6509.0  6.94  6.91  4.25
# 16276   1.51  Premium     H     SI2   62.9   58.0  6511.0  7.31  7.26  4.58
# 16277   1.51    Ideal     I     VS2   60.7   57.0  6511.0  7.42  7.35  4.48
# 16278   1.51     Good     J     SI1   64.1   61.0  6511.0  7.19  7.16  4.60
# 16279   1.20    Ideal     H     SI1   62.0    NaN     NaN   NaN   NaN   NaN
#
# [16280 rows x 10 columns]

# %%
sns.boxplot(df['table']) # in box plot only numerical values are used
# the values represented in shape of circles are called outliers. these outliers represent the major difference fron the main data
# Out:
# <Axes: ylabel='table'>

# %%
sns.boxplot(df['depth']) # in box plot only numerical values are used
# the values represented in shape of circles are called outliers. these outliers represent the major difference fron the main data
# Out:
# <Axes: ylabel='depth'>
